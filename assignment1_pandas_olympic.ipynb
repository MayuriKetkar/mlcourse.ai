# %%
import pandas as pd

# %%
# Change the path to the dataset file if needed. 
PATH = 'C:\\Users\\m.k\\MLcourse.ai\\Assign1\\athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data_1996=data[(data.Year==1996)]

# %%
data_1996[data_1996.Age==data_1996.Age.min()]
# Out:
#           ID          Name Sex   Age  Height  Weight      Team  NOC  \
# 93850  47506  Hem Reaksmey   F  12.0   175.0    65.0  Cambodia  CAM
#
#              Games  Year  Season     City     Sport  \
# 93850  1996 Summer  1996  Summer  Atlanta  Swimming
#
#                                           Event Medal
# 93850  Swimming Women's 100 metres Breaststroke   NaN

# %%
data_1996[(data_1996.Sex=='M')]['Age'].min()
data_1996[(data_1996.Sex=='F')]['Age'].min()
# Out:
# 12.0

# %%
data.Sport.unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
data[(data.Year==2000) & (data.Sport=='Gymnastics') & (data.Sex=='M')].ID.count() / data[(data.Year==2000) & (data.Sex=='M')].ID.count()
# Out:
# 0.07651966626936829

# %%
data[(data.Year==2000) & (data.Sex=='M')].ID.count()
# Out:
# 8390

# %%
data[(data.Year==2000) & (data.Sex=='F') & (data.Sport=='Basketball')].describe()
# Out:
#                   ID         Age      Height      Weight    Year
# count     142.000000  142.000000  142.000000  142.000000   142.0
# mean    65981.295775   26.690141  182.387324   73.464789  2000.0
# std     38666.204358    4.185729    9.139462    9.002491     0.0
# min       580.000000   17.000000  162.000000   58.000000  2000.0
# 25%     33914.250000   24.000000  175.000000   67.000000  2000.0
# 50%     64471.500000   27.000000  182.000000   73.000000  2000.0
# 75%     96557.000000   30.000000  190.000000   80.000000  2000.0
# max    135105.000000   37.000000  213.000000  100.000000  2000.0

# %%
print(data[(data.Year==2002)].Weight.max())
data[(data.Year==2002) & (data.Weight==123)]
# Out:
# 123.0
#           ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 99154  50171  Emmanuel Hostache   M  26.0   190.0   123.0  France  FRA
#
#              Games  Year  Season            City      Sport  \
# 99154  2002 Winter  2002  Winter  Salt Lake City  Bobsleigh
#
#                      Event Medal
# 99154  Bobsleigh Men's Two   NaN

# %%
data[(data.Name=='Pawe Abratkiewicz')].Year
# Out:
# 997     1992
# 998     1992
# 999     1998
# 1000    1998
# 1001    2002
# 1002    2002
# Name: Year, dtype: int64

# %%
data[(data.Year==2016) & (data.Team=='Switzerland')].Medal.count()
# Out:
# 11

# %%
data[(data.Year==2016) & (data.Team=='Serbia')].Medal.count()
# Out:
# 54

# %%
data[(data.Year==2014) & (data.Age >= 45) & (data.Age <= 45)].ID.count()
# Out:
# 1

# %%
data[(data.Year==2014) & (data.Age >= 25) & (data.Age <= 34)].ID.count()
# Out:
# 2594

# %%
data[(data.Year==2014) & (data.Age >= 15) & (data.Age <= 24)].ID.count()
# Out:
# 2027

# %%
data[(data.Year==2014) & (data.Age >= 35) & (data.Age <= 44)].ID.count()
# Out:
# 265

# %%
data[(data.Season=='Summer') & (data.City=='Lake Placid')]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
data[(data.Season=='Winter') & (data.City=='Sankt Moritz')]
# Out:
#             ID                                      Name Sex   Age  Height  \
# 935        529           Karl Gustaf Emanuel Abrahamsson   M  31.0     NaN
# 1187       665                     Gilbert Achard-Picard   M  29.0     NaN
# 1439       802                    Tadeusz Ralf Adamowski   M  26.0   177.0
# 1454       810         Bridget Shirley Adams (-Bengough)   F  19.0     NaN
# 2707      1508                            Enrico Airoldi   M  24.0     NaN
# 2708      1509                              Remo Airoldi   M  26.0     NaN
# 5053      2876                  Theodor "Theo" Allenbach   M  23.0     NaN
# 5054      2876                  Theodor "Theo" Allenbach   M  23.0     NaN
# 5132      2921                           Fernando Alloni   M  22.0     NaN
# 5332      3022                    Pentti Johannes Alonen   M  22.0   172.0
# 5333      3022                    Pentti Johannes Alonen   M  22.0   172.0
# ...

# %%
data[(data.Year==2016)].Sport.nunique()
# Out:
# 34

# %%
data[(data.Year==2000) & (data.Team=='Australia') & (data.Medal=='Silver') & (data.Sport=='Tennis')].ID.count()
# Out:
# 2
